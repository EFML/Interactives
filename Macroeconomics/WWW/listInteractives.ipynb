# %%
#!/usr/bin/env python
import os
from jinja2 import Environment, FileSystemLoader

# %%
PATH = os.path.dirname(os.path.abspath("__file__"))
TEMPLATE_ENVIRONMENT = Environment(
    autoescape=False,
    loader=FileSystemLoader(os.path.join(PATH, 'templates')),
    trim_blocks=False)

ignorePaths = set(['../.ipynb_checkpoints','../OldStructure','../Python','../SASS','../WWW'])

def render_template(template_filename, context):
    return TEMPLATE_ENVIRONMENT.get_template(template_filename).render(context)
 
def crawl_directory_for_html(directory):
    iList=[]
    actList=[]
    for dirpath, subdirs, files in os.walk(directory):
        for file in files:
            relURL = os.path.join(dirpath, file)  #e.g., ../11_Loanable_Funds/LC1/(file.html)
            unit = relURL.split('/')[0]  #e.g., 11_Loanable_Funds
            baseURL = 'https://dnextinteractives.s3.amazonaws.com/Macroeconomics/'
            
            #Create S3 Link
            link = baseURL + relURL.lstrip('../')
            if file.endswith('.html'):
                if "OldStructure" in link or "WWW" in link: 
                    a = True
#                     print "Ignore folder: %s" % dirpath
                else:
                    iList.append(link)
    
            if "ActTable" in file:
#                 print link
                actList.append(link)
    

# def new_crawl_directory_for_html(directory):
#     iList=[]
#     actList=[]
#     units={}
#     for dirpath, subdirs, files in os.walk(directory):
#         r = dirpath.split('/')
#         if len(r)>2:
#             if any(x not in dirpath for x in ignorePaths): 
#                 name = r[1]
#                 LC = r[2]
#                 print name,LC

#                 for file in files:
#                     if file.endswith('.html'):
#                         relURL = os.path.join(dirpath, file)  #e.g., ../11_Loanable_Funds/LC1/(file.html)
#                         unit = relURL.split('/')[0]  #e.g., 11_Loanable_Funds
#                         baseURL = 'https://dnextinteractives.s3.amazonaws.com/Macroeconomics/'



#                         #Create S3 Link
#                         link = baseURL + relURL.lstrip('../')
#                         print "Folder: %s" % dirpath
#                         iList.append(link)

#                         if "ActTable" in file:
#                 #                 print link
#                             actList.append(link)
    
            
    return iList, actList 

def create_index_html():
    fname = "MacroInteractives.html"
    iList, actList = new_crawl_directory_for_html('../')
    context = {
        'TotalInteractives': len(iList) + len(actList),
        'JSXlist': iList,
        'actList': actList
    }
    
    with open(fname, 'w') as f:
        html = render_template('interactives.html', context)
        f.write(html)
 
 
def main():
    create_index_html()
 
########################################
 
if __name__ == "__main__":
    main()
# Out:
# ['..', '0_Synthesis', '6_Board']
# 0_Synthesis 6_Board
# Folder: ../0_Synthesis/6_Board
# ['..', '0_Synthesis', '6_Board', '.ipynb_checkpoints']
# 0_Synthesis 6_Board
# ['..', '10_Money_Creation', 'LC2']
# 10_Money_Creation LC2
# ['..', '11_Monetary_Policy', 'LC2']
# 11_Monetary_Policy LC2
# Folder: ../11_Monetary_Policy/LC2
# Folder: ../11_Monetary_Policy/LC2
# Folder: ../11_Monetary_Policy/LC2
# ['..', '11_Monetary_Policy', 'LC2', '.ipynb_checkpoints']
# 11_Monetary_Policy LC2
# ['..', '11_Monetary_Policy', 'LC3']
# 11_Monetary_Policy LC3
# Folder: ../11_Monetary_Policy/LC3
# Folder: ../11_Monetary_Policy/LC3
# ['..', '11_Monetary_Policy', 'LC3', '.ipynb_checkpoints']
# 11_Monetary_Policy LC3
# ['..', '12_Loanable_Funds', 'LC1']
# 12_Loanable_Funds LC1
# Folder: ../12_Loanable_Funds/LC1
# ['..', '12_Loanable_Funds', 'LC2']
# 12_Loanable_Funds LC2
# Folder: ../12_Loanable_Funds/LC2
# Folder: ../12_Loanable_Funds/LC2
# ['..', '12_Loanable_Funds', 'LC2', '.ipynb_checkpoints']
# 12_Loanable_Funds LC2
# ['..', '13_Phillips_Curve', 'LC1']
# 13_Phillips_Curve LC1
# Folder: ../13_Phillips_Curve/LC1
# Folder: ../13_Phillips_Curve/LC1
# ['..', '13_Phillips_Curve', 'LC1', '.ipynb_checkpoints']
# 13_Phillips_Curve LC1
# ['..', '13_Phillips_Curve', 'LC2']
# 13_Phillips_Curve LC2
# Folder: ../13_Phillips_Curve/LC2
# ['..', '13_Phillips_Curve', 'LC2', '.ipynb_checkpoints']
# 13_Phillips_Curve LC2
# ['..', '13_Phillips_Curve', 'LC3']
# 13_Phillips_Curve LC3
# Folder: ../13_Phillips_Curve/LC3
# Folder: ../13_Phillips_Curve/LC3
# ['..', '13_Phillips_Curve', 'LC3', '.ipynb_checkpoints']
# 13_Phillips_Curve LC3
# ['..', '14_Foreign_Exchange', 'LC1']
# 14_Foreign_Exchange LC1
# Folder: ../14_Foreign_Exchange/LC1
# Folder: ../14_Foreign_Exchange/LC1
# Folder: ../14_Foreign_Exchange/LC1
# Folder: ../14_Foreign_Exchange/LC1
# ['..', '14_Foreign_Exchange', 'LC1', '.ipynb_checkpoints']
# 14_Foreign_Exchange LC1
# ['..', '14_Foreign_Exchange', 'LC2']
# 14_Foreign_Exchange LC2
# Folder: ../14_Foreign_Exchange/LC2
# Folder: ../14_Foreign_Exchange/LC2
# Folder: ../14_Foreign_Exchange/LC2
# Folder: ../14_Foreign_Exchange/LC2
# ['..', '14_Foreign_Exchange', 'LC2', '.ipynb_checkpoints']
# 14_Foreign_Exchange LC2
# ['..', '3_Economic_Growth', 'LC2']
# 3_Economic_Growth LC2
# Folder: ../3_Economic_Growth/LC2
# Folder: ../3_Economic_Growth/LC2
# ['..', '3_Economic_Growth', 'LC2', '.ipynb_checkpoints']
# 3_Economic_Growth LC2
# ['..', '3_Economic_Growth', 'LC3']
# 3_Economic_Growth LC3
# Folder: ../3_Economic_Growth/LC3
# ['..', '3_Economic_Growth', 'LC3', '.ipynb_checkpoints']
# 3_Economic_Growth LC3
# ['..', '4_Aggregate_Demand', 'LC1']
# 4_Aggregate_Demand LC1
# Folder: ../4_Aggregate_Demand/LC1
# Folder: ../4_Aggregate_Demand/LC1
# Folder: ../4_Aggregate_Demand/LC1
# Folder: ../4_Aggregate_Demand/LC1
# Folder: ../4_Aggregate_Demand/LC1
# Folder: ../4_Aggregate_Demand/LC1
# Folder: ../4_Aggregate_Demand/LC1
# Folder: ../4_Aggregate_Demand/LC1
# ['..', '4_Aggregate_Demand', 'LC1', '.ipynb_checkpoints']
# 4_Aggregate_Demand LC1
# ['..', '4_Aggregate_Demand', 'LC2']
# 4_Aggregate_Demand LC2
# Folder: ../4_Aggregate_Demand/LC2
# Folder: ../4_Aggregate_Demand/LC2
# Folder: ../4_Aggregate_Demand/LC2
# Folder: ../4_Aggregate_Demand/LC2
# Folder: ../4_Aggregate_Demand/LC2
# Folder: ../4_Aggregate_Demand/LC2
# ['..', '4_Aggregate_Demand', 'LC2', '.ipynb_checkpoints']
# 4_Aggregate_Demand LC2
# ['..', '4_Aggregate_Demand', 'LC2_Test_Dashed']
# 4_Aggregate_Demand LC2_Test_Dashed
# ['..', '4_Aggregate_Demand', 'LC3']
# 4_Aggregate_Demand LC3
# Folder: ../4_Aggregate_Demand/LC3
# Folder: ../4_Aggregate_Demand/LC3
# ['..', '4_Aggregate_Demand', 'LC3', '.ipynb_checkpoints']
# 4_Aggregate_Demand LC3
# ['..', '5_Aggregate_Supply', 'LC1']
# 5_Aggregate_Supply LC1
# Folder: ../5_Aggregate_Supply/LC1
# Folder: ../5_Aggregate_Supply/LC1
# Folder: ../5_Aggregate_Supply/LC1
# Folder: ../5_Aggregate_Supply/LC1
# Folder: ../5_Aggregate_Supply/LC1
# ['..', '5_Aggregate_Supply', 'LC1', 'Images']
# 5_Aggregate_Supply LC1
# Folder: ../5_Aggregate_Supply/LC1/Images
# ['..', '5_Aggregate_Supply', 'LC1', 'Images', '.ipynb_checkpoints']
# 5_Aggregate_Supply LC1
# ['..', '5_Aggregate_Supply', 'LC2']
# 5_Aggregate_Supply LC2
# Folder: ../5_Aggregate_Supply/LC2
# ['..', '5_Aggregate_Supply', 'LC2', '.ipynb_checkpoints']
# 5_Aggregate_Supply LC2
# ['..', '6_ShortRun_Equilibrium', 'LC1']
# 6_ShortRun_Equilibrium LC1
# Folder: ../6_ShortRun_Equilibrium/LC1
# Folder: ../6_ShortRun_Equilibrium/LC1
# Folder: ../6_ShortRun_Equilibrium/LC1
# ['..', '6_ShortRun_Equilibrium', 'LC1', '.ipynb_checkpoints']
# 6_ShortRun_Equilibrium LC1
# ['..', '6_ShortRun_Equilibrium', 'LC2']
# 6_ShortRun_Equilibrium LC2
# Folder: ../6_ShortRun_Equilibrium/LC2
# Folder: ../6_ShortRun_Equilibrium/LC2
# Folder: ../6_ShortRun_Equilibrium/LC2
# Folder: ../6_ShortRun_Equilibrium/LC2
# ['..', '6_ShortRun_Equilibrium', 'LC2', '.ipynb_checkpoints']
# 6_ShortRun_Equilibrium LC2
# ['..', '6_ShortRun_Equilibrium', 'LC2', 'oldLC2']
# 6_ShortRun_Equilibrium LC2
# Folder: ../6_ShortRun_Equilibrium/LC2/oldLC2
# Folder: ../6_ShortRun_Equilibrium/LC2/oldLC2
# ['..', '6_ShortRun_Equilibrium', 'LC3']
# 6_ShortRun_Equilibrium LC3
# Folder: ../6_ShortRun_Equilibrium/LC3
# Folder: ../6_ShortRun_Equilibrium/LC3
# Folder: ../6_ShortRun_Equilibrium/LC3
# Folder: ../6_ShortRun_Equilibrium/LC3
# ['..', '6_ShortRun_Equilibrium', 'LC3', '.ipynb_checkpoints']
# 6_ShortRun_Equilibrium LC3
# ['..', '6_ShortRun_Equilibrium', 'LC3', 'oldLC3']
# 6_ShortRun_Equilibrium LC3
# Folder: ../6_ShortRun_Equilibrium/LC3/oldLC3
# Folder: ../6_ShortRun_Equilibrium/LC3/oldLC3
# ['..', '7_Moving_to_Long_Run_Equil', 'LC2']
# 7_Moving_to_Long_Run_Equil LC2
# Folder: ../7_Moving_to_Long_Run_Equil/LC2
# Folder: ../7_Moving_to_Long_Run_Equil/LC2
# Folder: ../7_Moving_to_Long_Run_Equil/LC2
# ['..', '7_Moving_to_Long_Run_Equil', 'LC2', '.ipynb_checkpoints']
# 7_Moving_to_Long_Run_Equil LC2
# ['..', '7_Moving_to_Long_Run_Equil', 'LC3']
# 7_Moving_to_Long_Run_Equil LC3
# Folder: ../7_Moving_to_Long_Run_Equil/LC3
# Folder: ../7_Moving_to_Long_Run_Equil/LC3
# Folder: ../7_Moving_to_Long_Run_Equil/LC3
# ['..', '7_Moving_to_Long_Run_Equil', 'LC3', '.ipynb_checkpoints']
# 7_Moving_to_Long_Run_Equil LC3
# ['..', '8_Fiscal_Policy', 'LC1']
# 8_Fiscal_Policy LC1
# Folder: ../8_Fiscal_Policy/LC1
# Folder: ../8_Fiscal_Policy/LC1
# Folder: ../8_Fiscal_Policy/LC1
# ['..', '8_Fiscal_Policy', 'LC1', '.ipynb_checkpoints']
# 8_Fiscal_Policy LC1
# ['..', '8_Fiscal_Policy', 'LC1', 'badcopy']
# 8_Fiscal_Policy LC1
# Folder: ../8_Fiscal_Policy/LC1/badcopy
# ['..', '8_Fiscal_Policy', 'LC2']
# 8_Fiscal_Policy LC2
# Folder: ../8_Fiscal_Policy/LC2
# Folder: ../8_Fiscal_Policy/LC2
# Folder: ../8_Fiscal_Policy/LC2
# ['..', '8_Fiscal_Policy', 'LC2', '.ipynb_checkpoints']
# 8_Fiscal_Policy LC2
# ['..', '8_Fiscal_Policy', 'LC3']
# 8_Fiscal_Policy LC3
# Folder: ../8_Fiscal_Policy/LC3
# Folder: ../8_Fiscal_Policy/LC3
# ['..', '8_Fiscal_Policy', 'LC3', '.ipynb_checkpoints']
# 8_Fiscal_Policy LC3
# ['..', '9_Money_and_Money_Market', 'LC2']
# 9_Money_and_Money_Market LC2
# Folder: ../9_Money_and_Money_Market/LC2
# Folder: ../9_Money_and_Money_Market/LC2
# Folder: ../9_Money_and_Money_Market/LC2
# ['..', '9_Money_and_Money_Market', 'LC2', '.ipynb_checkpoints']
# 9_Money_and_Money_Market LC2
# ['..', '9_Money_and_Money_Market', 'LC3']
# 9_Money_and_Money_Market LC3
# Folder: ../9_Money_and_Money_Market/LC3
# Folder: ../9_Money_and_Money_Market/LC3
# Folder: ../9_Money_and_Money_Market/LC3
# ['..', '9_Money_and_Money_Market', 'LC3', '.ipynb_checkpoints']
# 9_Money_and_Money_Market LC3
# ['..', '9_Money_and_Money_Market', 'LC4']
# 9_Money_and_Money_Market LC4
# Folder: ../9_Money_and_Money_Market/LC4
# Folder: ../9_Money_and_Money_Market/LC4
# Folder: ../9_Money_and_Money_Market/LC4
# ['..', '9_Money_and_Money_Market', 'LC4', '.ipynb_checkpoints']
# 9_Money_and_Money_Market LC4
# ['..', 'Images', '.ipynb_checkpoints']
# Images .ipynb_checkpoints
# ['..', 'OldStructure', 'Aggregate_Demand']
# OldStructure Aggregate_Demand
# ['..', 'OldStructure', 'Aggregate_Demand', 'LC1']
# OldStructure Aggregate_Demand
# Folder: ../OldStructure/Aggregate_Demand/LC1
# Folder: ../OldStructure/Aggregate_Demand/LC1
# Folder: ../OldStructure/Aggregate_Demand/LC1
# Folder: ../OldStructure/Aggregate_Demand/LC1
# Folder: ../OldStructure/Aggregate_Demand/LC1
# Folder: ../OldStructure/Aggregate_Demand/LC1
# ['..', 'OldStructure', 'Aggregate_Demand', 'LC1', '.ipynb_checkpoints']
# OldStructure Aggregate_Demand
# ['..', 'OldStructure', 'JS']
# OldStructure JS
# ['..', 'OldStructure', 'Loanable_Funds']
# OldStructure Loanable_Funds
# Folder: ../OldStructure/Loanable_Funds
# Folder: ../OldStructure/Loanable_Funds
# ['..', 'OldStructure', 'Loanable_Funds', '.ipynb_checkpoints']
# OldStructure Loanable_Funds
# ['..', 'OldStructure', 'Money_and_the_Money_Market']
# OldStructure Money_and_the_Money_Market
# ['..', 'OldStructure', 'Money_and_the_Money_Market', '.ipynb_checkpoints']
# OldStructure Money_and_the_Money_Market
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'LC2']
# OldStructure Money_and_the_Money_Market
# Folder: ../OldStructure/Money_and_the_Money_Market/LC2
# Folder: ../OldStructure/Money_and_the_Money_Market/LC2
# Folder: ../OldStructure/Money_and_the_Money_Market/LC2
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'LC2', '.ipynb_checkpoints']
# OldStructure Money_and_the_Money_Market
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'LC2', 'old']
# OldStructure Money_and_the_Money_Market
# Folder: ../OldStructure/Money_and_the_Money_Market/LC2/old
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'LC2', 'old', '.ipynb_checkpoints']
# OldStructure Money_and_the_Money_Market
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'LC2_Activity2_ActiveTable']
# OldStructure Money_and_the_Money_Market
# Folder: ../OldStructure/Money_and_the_Money_Market/LC2_Activity2_ActiveTable
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'LC3']
# OldStructure Money_and_the_Money_Market
# Folder: ../OldStructure/Money_and_the_Money_Market/LC3
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'LC3', '.ipynb_checkpoints']
# OldStructure Money_and_the_Money_Market
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'LC3_Sally']
# OldStructure Money_and_the_Money_Market
# Folder: ../OldStructure/Money_and_the_Money_Market/LC3_Sally
# Folder: ../OldStructure/Money_and_the_Money_Market/LC3_Sally
# Folder: ../OldStructure/Money_and_the_Money_Market/LC3_Sally
# Folder: ../OldStructure/Money_and_the_Money_Market/LC3_Sally
# Folder: ../OldStructure/Money_and_the_Money_Market/LC3_Sally
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'LC3_Sally', '.ipynb_checkpoints']
# OldStructure Money_and_the_Money_Market
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'LC4']
# OldStructure Money_and_the_Money_Market
# Folder: ../OldStructure/Money_and_the_Money_Market/LC4
# Folder: ../OldStructure/Money_and_the_Money_Market/LC4
# Folder: ../OldStructure/Money_and_the_Money_Market/LC4
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'LC4', '.ipynb_checkpoints']
# OldStructure Money_and_the_Money_Market
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'old_LC3']
# OldStructure Money_and_the_Money_Market
# Folder: ../OldStructure/Money_and_the_Money_Market/old_LC3
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'old_LC3', '.ipynb_checkpoints']
# OldStructure Money_and_the_Money_Market
# ['..', 'OldStructure', 'Money_and_the_Money_Market', 'refactor']
# OldStructure Money_and_the_Money_Market
# ['..', 'OldStructure', 'Moving_to_Long_Run_Equlibrium']
# OldStructure Moving_to_Long_Run_Equlibrium
# ['..', 'OldStructure', 'Moving_to_Long_Run_Equlibrium', '.ipynb_checkpoints']
# OldStructure Moving_to_Long_Run_Equlibrium
# ['..', 'OldStructure', 'Moving_to_Long_Run_Equlibrium', 'LC2']
# OldStructure Moving_to_Long_Run_Equlibrium
# Folder: ../OldStructure/Moving_to_Long_Run_Equlibrium/LC2
# Folder: ../OldStructure/Moving_to_Long_Run_Equlibrium/LC2
# Folder: ../OldStructure/Moving_to_Long_Run_Equlibrium/LC2
# ['..', 'OldStructure', 'Moving_to_Long_Run_Equlibrium', 'LC2', '.ipynb_checkpoints']
# OldStructure Moving_to_Long_Run_Equlibrium
# ['..', 'OldStructure', 'Moving_to_Long_Run_Equlibrium', 'LC3']
# OldStructure Moving_to_Long_Run_Equlibrium
# Folder: ../OldStructure/Moving_to_Long_Run_Equlibrium/LC3
# Folder: ../OldStructure/Moving_to_Long_Run_Equlibrium/LC3
# ['..', 'OldStructure', 'Moving_to_Long_Run_Equlibrium', 'LC3', '.ipynb_checkpoints']
# OldStructure Moving_to_Long_Run_Equlibrium
# ['..', 'OldStructure', 'Phillips_Curve']
# OldStructure Phillips_Curve
# ['..', 'OldStructure', 'Phillips_Curve', '.ipynb_checkpoints']
# OldStructure Phillips_Curve
# ['..', 'OldStructure', 'Phillips_Curve', 'LC1']
# OldStructure Phillips_Curve
# Folder: ../OldStructure/Phillips_Curve/LC1
# Folder: ../OldStructure/Phillips_Curve/LC1
# Folder: ../OldStructure/Phillips_Curve/LC1
# ['..', 'OldStructure', 'Phillips_Curve', 'LC1', '.ipynb_checkpoints']
# OldStructure Phillips_Curve
# ['..', 'OldStructure', 'Phillips_Curve', 'LC2']
# OldStructure Phillips_Curve
# Folder: ../OldStructure/Phillips_Curve/LC2
# Folder: ../OldStructure/Phillips_Curve/LC2
# Folder: ../OldStructure/Phillips_Curve/LC2
# ['..', 'OldStructure', 'Phillips_Curve', 'LC2', '.ipynb_checkpoints']
# OldStructure Phillips_Curve
# ['..', 'OldStructure', 'Phillips_Curve', 'LC3']
# OldStructure Phillips_Curve
# Folder: ../OldStructure/Phillips_Curve/LC3
# Folder: ../OldStructure/Phillips_Curve/LC3
# Folder: ../OldStructure/Phillips_Curve/LC3
# Folder: ../OldStructure/Phillips_Curve/LC3
# Folder: ../OldStructure/Phillips_Curve/LC3
# ['..', 'OldStructure', 'Phillips_Curve', 'LC3', '.ipynb_checkpoints']
# OldStructure Phillips_Curve
# ['..', 'OldStructure', 'refactor']
# OldStructure refactor
# Folder: ../OldStructure/refactor
# ['..', 'OldStructure', 'refactor', '.ipynb_checkpoints']
# OldStructure refactor
# ['..', 'OldStructure', 'Template_1.0']
# OldStructure Template_1.0
# Folder: ../OldStructure/Template_1.0
# ['..', 'OldStructure', 'Template_1.0', '.ipynb_checkpoints']
# OldStructure Template_1.0
# ['..', 'Python', '.ipynb_checkpoints']
# Python .ipynb_checkpoints
# ['..', 'WWW', '.ipynb_checkpoints']
# WWW .ipynb_checkpoints
# ['..', 'WWW', 'scripts']
# WWW scripts
# ['..', 'WWW', 'simpleJinjaExample']
# WWW simpleJinjaExample
# ['..', 'WWW', 'simpleJinjaExample', '.ipynb_checkpoints']
# WWW simpleJinjaExample
# ['..', 'WWW', 'simpleJinjaExample', 'templates']
# WWW simpleJinjaExample
# Folder: ../WWW/simpleJinjaExample/templates
# Folder: ../WWW/simpleJinjaExample/templates
# ['..', 'WWW', 'styles']
# WWW styles
# ['..', 'WWW', 'templates']
# WWW templates
# Folder: ../WWW/templates
# Folder: ../WWW/templates
# Folder: ../WWW/templates
# ['..', 'WWW', 'templates', 'old']
# WWW templates
# Folder: ../WWW/templates/old
# Folder: ../WWW/templates/old
# Folder: ../WWW/templates/old
# ['..', 'WWW', 'templates', 'old', 'test']
# WWW templates
# Folder: ../WWW/templates/old/test
# Folder: ../WWW/templates/old/test
# Folder: ../WWW/templates/old/test

# %%
[word in dirpath for word in ignorePaths]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-b154892c627d> in <module>()
# ----> 1 [word in dirpath for word in ignorePaths]
#
# NameError: name 'dirpath' is not defined
